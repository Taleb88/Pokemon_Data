# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.to_excel('pokemon_data.xlsx', index=False)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# grabbing rows with attack >= 100 and defense >= 80
new_df = df.loc[(df['Attack'] >= 100) & (df['Defense'] >= 80)]

# %%
new_df
# Out:
#        #                       Name  Type 1  Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur   Grass  Poison    625   80     100
# 7      6  CharizardMega Charizard X    Fire  Dragon    634   78     130
# 12     9    BlastoiseMega Blastoise   Water     NaN    630   79     103
# 33    28                  Sandslash  Ground     NaN    450   75     100
# 64    59                   Arcanine    Fire     NaN    555   90     110
# ..   ...                        ...     ...     ...    ...  ...     ...
# 793  717                    Yveltal    Dark  Flying    680  126     131
# 794  718           Zygarde50% Forme  Dragon  Ground    600  108     100
# 795  719                    Diancie    Rock   Fairy    600   50     100
# 796  719        DiancieMega Diancie    Rock   Fairy    700   50     160
# 799  721                  Volcanion    Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# saving filtered results in new csv/workbook
new_df.to_csv('filtered_data.csv', index=False)
new_df.to_excel('filtered_data.xlsx',index=False)

# %%
# index reset
new_df.reset_index(drop=True, inplace=True)

# %%
new_df
# saving filtered results in new csv/workbook
new_df.to_csv('filtered_data.csv', index=False)
new_df.to_excel('filtered_data.xlsx',index=False)

# %%
for index,row in new_df.iterrows():
    print(index, row['Name'])
# Out:
# 0 VenusaurMega Venusaur
# 1 CharizardMega Charizard X
# 2 BlastoiseMega Blastoise
# 3 Sandslash
# 4 Arcanine
# 5 Machamp
# 6 Golem
# 7 Krabby
# 8 Kingler
# 9 Rhydon
# 10 KangaskhanMega Kangaskhan
# 11 Scyther
# 12 Pinsir
# 13 PinsirMega Pinsir
# 14 Tauros
# 15 GyaradosMega Gyarados
# 16 Kabutops
# 17 AerodactylMega Aerodactyl
# 18 Moltres
# 19 Dragonite
# 20 Mewtwo
# 21 MewtwoMega Mewtwo X
# 22 Mew
# 23 Feraligatr
# 24 Sudowoodo
# 25 SteelixMega Steelix
# 26 Scizor
# 27 ScizorMega Scizor
# 28 HeracrossMega Heracross
# 29 Piloswine
# 30 Donphan
# 31 Entei
# 32 Tyranitar
# 33 TyranitarMega Tyranitar
# 34 Ho-oh
# 35 Celebi
# 36 BlazikenMega Blaziken
# 37 Swampert
# 38 SwampertMega Swampert
# 39 Breloom
# 40 Slaking
# 41 MawileMega Mawile
# 42 Aggron
# 43 AggronMega Aggron
# 44 MedichamMega Medicham
# 45 CameruptMega Camerupt
# 46 Flygon
# 47 AltariaMega Altaria
# 48 Crawdaunt
# 49 Armaldo
# 50 GlalieMega Glalie
# 51 Huntail
# 52 Salamence
# 53 SalamenceMega Salamence
# 54 Metagross
# ...

# %%
# filtering out rows with names containing "Sala" or "sala"
new_df.loc[new_df['Name'].str.contains('(?i)sala')]
# Out:
#       #                     Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 52  373                Salamence  Dragon  Flying    600  95     135       80
# 53  373  SalamenceMega Salamence  Dragon  Flying    700  95     145      130
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 52      110       80    100           3      False
# 53      120       90    120           3      False

# %%
# filtering out rows that do not contain "Sala" or "sala"
new_df.loc[~new_df['Name'].str.contains('(?i)sala')]
# Out:
#        #                       Name  Type 1  Type 2  Total   HP  Attack  \
# 0      3      VenusaurMega Venusaur   Grass  Poison    625   80     100
# 1      6  CharizardMega Charizard X    Fire  Dragon    634   78     130
# 2      9    BlastoiseMega Blastoise   Water     NaN    630   79     103
# 3     28                  Sandslash  Ground     NaN    450   75     100
# 4     59                   Arcanine    Fire     NaN    555   90     110
# ..   ...                        ...     ...     ...    ...  ...     ...
# 130  717                    Yveltal    Dark  Flying    680  126     131
# 131  718           Zygarde50% Forme  Dragon  Ground    600  108     100
# 132  719                    Diancie    Rock   Fairy    600   50     100
# 133  719        DiancieMega Diancie    Rock   Fairy    700   50     160
# 134  721                  Volcanion    Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# filtering out rows that contain "Poison" or attack <= 150
new_df.loc[new_df['Type 2'].str.contains('(?i)poison|nan', na=False)]
# Out:
#       #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0     3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 98  545              Scolipede    Bug  Poison    485  60     100       89
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       122      120     80           1      False
# 98       55       69    112           5      False

# %%
new_df
# Out:
#        #                       Name  Type 1  Type 2  Total   HP  Attack  \
# 0      3      VenusaurMega Venusaur   Grass  Poison    625   80     100
# 1      6  CharizardMega Charizard X    Fire  Dragon    634   78     130
# 2      9    BlastoiseMega Blastoise   Water     NaN    630   79     103
# 3     28                  Sandslash  Ground     NaN    450   75     100
# 4     59                   Arcanine    Fire     NaN    555   90     110
# ..   ...                        ...     ...     ...    ...  ...     ...
# 130  717                    Yveltal    Dark  Flying    680  126     131
# 131  718           Zygarde50% Forme  Dragon  Ground    600  108     100
# 132  719                    Diancie    Rock   Fairy    600   50     100
# 133  719        DiancieMega Diancie    Rock   Fairy    700   50     160
# 134  721                  Volcanion    Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# replace "Fairy" values with "Magical"
new_df.loc[new_df['Type 2'] == 'Fairy', 'Type 2'] = 'Magical'

# %%
new_df
# Out:
#        #                       Name  Type 1   Type 2  Total   HP  Attack  \
# 0      3      VenusaurMega Venusaur   Grass   Poison    625   80     100
# 1      6  CharizardMega Charizard X    Fire   Dragon    634   78     130
# 2      9    BlastoiseMega Blastoise   Water      NaN    630   79     103
# 3     28                  Sandslash  Ground      NaN    450   75     100
# 4     59                   Arcanine    Fire      NaN    555   90     110
# ..   ...                        ...     ...      ...    ...  ...     ...
# 130  717                    Yveltal    Dark   Flying    680  126     131
# 131  718           Zygarde50% Forme  Dragon   Ground    600  108     100
# 132  719                    Diancie    Rock  Magical    600   50     100
# 133  719        DiancieMega Diancie    Rock  Magical    700   50     160
# 134  721                  Volcanion    Fire    Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45     49       49
# 1      2                Ivysaur    Grass  Poison    405  60     62       63
# 2      3               Venusaur    Grass  Poison    525  80     82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80    100      123
# 4      4             Charmander     Fire     NaN    309  39     52       43
# ..   ...                    ...      ...     ...    ...  ..    ...      ...
# 795  719                Diancie     Rock   Fairy    600  50    100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50    160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80    110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80    160       60
# 799  721              Volcanion     Fire   Water    600  80    110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# only want filter out pokemon with Type 1 = 'Fire'
fire_df = df.loc[df['Type 1'] == 'Fire']

# %%
fire_df
# Out:
#        #                       Name Type 1    Type 2  Total   HP Attack  \
# 4      4                 Charmander   Fire       NaN    309   39     52
# 5      5                 Charmeleon   Fire       NaN    405   58     64
# 6      6                  Charizard   Fire    Flying    534   78     84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78    130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78    104
# 42    37                     Vulpix   Fire       NaN    299   38     41
# 43    38                  Ninetales   Fire       NaN    505   73     76
# 63    58                  Growlithe   Fire       NaN    350   55     70
# 64    59                   Arcanine   Fire       NaN    555   90    110
# 83    77                     Ponyta   Fire       NaN    410   50     85
# 84    78                   Rapidash   Fire       NaN    500   65    100
# 135  126                     Magmar   Fire       NaN    495   65     95
# ...

# %%
# save the fire pokemon data into csv/excel workbook
fire_df.to_csv('fire_pokemon.csv')
fire_df.to_excel('fire_pokemon.xlsx')

# %%
fire_df
# Out:
#        #                       Name Type 1    Type 2  Total   HP Attack  \
# 4      4                 Charmander   Fire       NaN    309   39     52
# 5      5                 Charmeleon   Fire       NaN    405   58     64
# 6      6                  Charizard   Fire    Flying    534   78     84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78    130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78    104
# 42    37                     Vulpix   Fire       NaN    299   38     41
# 43    38                  Ninetales   Fire       NaN    505   73     76
# 63    58                  Growlithe   Fire       NaN    350   55     70
# 64    59                   Arcanine   Fire       NaN    555   90    110
# 83    77                     Ponyta   Fire       NaN    410   50     85
# 84    78                   Rapidash   Fire       NaN    500   65    100
# 135  126                     Magmar   Fire       NaN    495   65     95
# ...

# %%
# lengendary pokemon should have a 200 attack and defense
fire_df.loc[fire_df['Legendary'] == True, ['Attack', 'Defense']] = 200

# %%
fire_df
# Out:
#            #                       Name Type 1    Type 2 Total     HP Attack  \
# 4        4.0                 Charmander   Fire       NaN   270   39.0     52
# 5        5.0                 Charmeleon   Fire       NaN   347   58.0     64
# 6        6.0                  Charizard   Fire    Flying   456   78.0     84
# 7        6.0  CharizardMega Charizard X   Fire    Dragon   556   78.0    130
# 8        6.0  CharizardMega Charizard Y   Fire    Flying   556   78.0    104
# 42      37.0                     Vulpix   Fire       NaN   261   38.0     41
# 43      38.0                  Ninetales   Fire       NaN   432   73.0     76
# 63      58.0                  Growlithe   Fire       NaN   295   55.0     70
# 64      59.0                   Arcanine   Fire       NaN   465   90.0    110
# 83      77.0                     Ponyta   Fire       NaN   360   50.0     85
# 84      78.0                   Rapidash   Fire       NaN   435   65.0    100
# ...

# %%
legendary_fire_pokemon_df = fire_df.loc[fire_df['Legendary'] == True]

# %%
legendary_fire_pokemon_df
# Out:
#            #       Name Type 1  Type 2 Total     HP Attack Defense  Sp. Atk  \
# 158    146.0    Moltres   Fire  Flying   700   90.0    200     200    125.0
# 263    244.0      Entei   Fire     NaN   665  115.0    200     200     90.0
# 270    250.0      Ho-oh   Fire  Flying   754  106.0    200     200    110.0
# 542    485.0    Heatran   Fire   Steel   713   91.0    200     200    130.0
# 799    721.0  Volcanion   Fire   Water   690   80.0    200     200    130.0
# Total    NaN        NaN    NaN     NaN   NaN    NaN    NaN     NaN      NaN
#
#        Sp. Def  Speed  Generation Legendary
# 158       85.0   90.0         1.0      True
# 263       75.0  100.0         2.0      True
# 270      154.0   90.0         2.0      True
# 542      106.0   77.0         4.0      True
# 799       90.0   70.0         6.0      True
# Total      NaN    NaN         NaN       NaN
